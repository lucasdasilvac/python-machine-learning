# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('iris.data', header=None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['sepal length in cm', 'sepal width in cm', 'petal length in cm', 'petal width in cm', 'class']

# %%
df['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
class_label_mapping = {'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2}

# %%
df['class'] = df['class'].map(class_label_mapping)

# %%
y = df['class'].values

# %%
df.drop(axis=1, inplace=True, labels='class')

# %%
X = df.values

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
y[0:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
X[0:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.9, random_state=42, shuffle=True, stratify=y)

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()

# %%
X_train_std = std.fit_transform(X_train)
X_test_std = std.transform(X_test)

# %%
X_train_std[0:5]
# Out:
# array([[ 1.19452367,  0.30570892,  0.62281135,  0.49431153],
#        [-0.10859306, -0.15285446,  0.24038333,  0.08238526],
#        [-1.62889591, -0.15285446, -1.45322649, -1.42801109],
#        [-0.10859306, -0.61141784,  0.24038333,  0.21969401],
#        [-0.76015142,  2.13996244, -1.28932877, -1.15339358]])

# %%
X_test_std[0:5]
# Out:
# array([[-1.30311673,  0.30570892, -1.23469619, -1.29070234],
#        [-0.76015142,  2.13996244, -1.28932877, -1.29070234],
#        [-0.76015142,  3.51565258, -1.18006362, -1.29070234],
#        [-1.30311673,  0.7642723 , -1.28932877, -1.29070234],
#        [-0.10859306, -1.06998122,  0.40428105,  0.21969401]])

# %% [markdown]
# # Euclidean Distance

# %%
def euclidean_distance(X, line):
    X_  = (X - line) ** 2
    return np.sqrt(np.sum(X_, axis=1))

# %%
df['class'] = y

# %%
df.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm  class
# 0                0.2      0
# 1                0.2      0
# 2                0.2      0
# 3                0.2      0
# 4                0.2      0

# %%
X[0:1,]
# Out:
# array([[5.1, 3.5, 1.4, 0.2]])

# %%
X_line = X[0:1,]

# %%
df['euclidean_distance'] = euclidean_distance(X, X_line)

# %%
df.sort_values(by='euclidean_distance')[0:25]
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 17                 5.1                3.5                 1.4
# 4                  5.0                3.6                 1.4
# 39                 5.1                3.4                 1.5
# 27                 5.2                3.5                 1.5
# 28                 5.2                3.4                 1.4
# 40                 5.0                3.5                 1.3
# 7                  5.0                3.4                 1.5
# 49                 5.0                3.3                 1.4
# 21                 5.1                3.7                 1.5
# 48                 5.3                3.7                 1.5
# 26                 5.0                3.4                 1.6
# 19                 5.1                3.8                 1.5
# 46                 5.1                3.8                 1.6
# 35                 5.0                3.2                 1.2
# 11                 4.8                3.4                 1.6
# 10                 5.4                3.7                 1.5
# 31                 5.4                3.4                 1.5
# 36                 5.5                3.5                 1.3
# 20                 5.4                3.4                 1.7
# 43                 5.0                3.5                 1.6
# 34                 4.9                3.1                 1.5
# 37                 4.9                3.1                 1.5
# 9                  4.9                3.1                 1.5
# 23                 5.1                3.3                 1.7
#
#     petal width in cm  class  euclidean_distance
# 0                 0.2      0            0.000000
# 17                0.3      0            0.100000
# 4                 0.2      0            0.141421
# 39                0.2      0            0.141421
# 27                0.2      0            0.141421
# 28                0.2      0            0.141421
# 40                0.3      0            0.173205
# 7                 0.2      0            0.173205
# 49                0.2      0            0.223607
# 21                0.4      0            0.300000
# 48                0.2      0            0.300000
# 26                0.4      0            0.316228
# 19                0.3      0            0.331662
# 46                0.2      0            0.360555
# 35                0.2      0            0.374166
# 11                0.2      0            0.374166
# 10                0.2      0            0.374166
# 31                0.4      0            0.387298
# 36                0.2      0            0.412311
# 20                0.2      0            0.435890
# 43                0.6      0            0.458258
# 34                0.1      0            0.469042
# 37                0.1      0            0.469042
# 9                 0.1      0            0.469042
# 23                0.5      0            0.469042

# %% [markdown]
# # Manhattan Distance

# %%
def manhattan_distance(X, line):
    X_ = abs((X - line))
    return np.sum(X_, axis=1)

# %%
df['manhattan_distance'] = manhattan_distance(X, X_line)

# %%
df.sort_values(by='manhattan_distance')[0:25]
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 17                 5.1                3.5                 1.4
# 4                  5.0                3.6                 1.4
# 39                 5.1                3.4                 1.5
# 28                 5.2                3.4                 1.4
# 27                 5.2                3.5                 1.5
# 40                 5.0                3.5                 1.3
# 7                  5.0                3.4                 1.5
# 49                 5.0                3.3                 1.4
# 19                 5.1                3.8                 1.5
# 46                 5.1                3.8                 1.6
# 36                 5.5                3.5                 1.3
# 21                 5.1                3.7                 1.5
# 48                 5.3                3.7                 1.5
# 35                 5.0                3.2                 1.2
# 26                 5.0                3.4                 1.6
# 11                 4.8                3.4                 1.6
# 10                 5.4                3.7                 1.5
# 1                  4.9                3.0                 1.4
# 43                 5.0                3.5                 1.6
# 6                  4.6                3.4                 1.4
# 20                 5.4                3.4                 1.7
# 31                 5.4                3.4                 1.5
# 2                  4.7                3.2                 1.3
# 9                  4.9                3.1                 1.5
#
#     petal width in cm  class  euclidean_distance  manhattan_distance
# 0                 0.2      0            0.000000                 0.0
# 17                0.3      0            0.100000                 0.1
# 4                 0.2      0            0.141421                 0.2
# 39                0.2      0            0.141421                 0.2
# 28                0.2      0            0.141421                 0.2
# 27                0.2      0            0.141421                 0.2
# 40                0.3      0            0.173205                 0.3
# 7                 0.2      0            0.173205                 0.3
# 49                0.2      0            0.223607                 0.3
# 19                0.3      0            0.331662                 0.5
# 46                0.2      0            0.360555                 0.5
# 36                0.2      0            0.412311                 0.5
# 21                0.4      0            0.300000                 0.5
# 48                0.2      0            0.300000                 0.5
# 35                0.2      0            0.374166                 0.6
# 26                0.4      0            0.316228                 0.6
# 11                0.2      0            0.374166                 0.6
# 10                0.2      0            0.374166                 0.6
# 1                 0.2      0            0.538516                 0.7
# 43                0.6      0            0.458258                 0.7
# 6                 0.3      0            0.519615                 0.7
# 20                0.2      0            0.435890                 0.7
# 31                0.4      0            0.387298                 0.7
# 2                 0.2      0            0.509902                 0.8
# 9                 0.1      0            0.469042                 0.8

# %% [markdown]
# # Chebyshev Distance

# %%
def chebyshev_distance(X, line):
    X_ = abs((X - line))
    return np.max(X_, axis=1)

# %%
df['chebyshev_distance'] = chebyshev_distance(X, X_line)

# %%
df.sort_values(by='chebyshev_distance')[0:25]
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 17                 5.1                3.5                 1.4
# 40                 5.0                3.5                 1.3
# 39                 5.1                3.4                 1.5
# 4                  5.0                3.6                 1.4
# 7                  5.0                3.4                 1.5
# 27                 5.2                3.5                 1.5
# 28                 5.2                3.4                 1.4
# 26                 5.0                3.4                 1.6
# 48                 5.3                3.7                 1.5
# 49                 5.0                3.3                 1.4
# 21                 5.1                3.7                 1.5
# 11                 4.8                3.4                 1.6
# 35                 5.0                3.2                 1.2
# 46                 5.1                3.8                 1.6
# 19                 5.1                3.8                 1.5
# 23                 5.1                3.3                 1.7
# 10                 5.4                3.7                 1.5
# 20                 5.4                3.4                 1.7
# 31                 5.4                3.4                 1.5
# 29                 4.7                3.2                 1.6
# 2                  4.7                3.2                 1.3
# 34                 4.9                3.1                 1.5
# 30                 4.8                3.1                 1.6
# 37                 4.9                3.1                 1.5
#
#     petal width in cm  class  euclidean_distance  manhattan_distance  \
# 0                 0.2      0            0.000000                 0.0
# 17                0.3      0            0.100000                 0.1
# 40                0.3      0            0.173205                 0.3
# 39                0.2      0            0.141421                 0.2
# 4                 0.2      0            0.141421                 0.2
# 7                 0.2      0            0.173205                 0.3
# 27                0.2      0            0.141421                 0.2
# 28                0.2      0            0.141421                 0.2
# 26                0.4      0            0.316228                 0.6
# 48                0.2      0            0.300000                 0.5
# 49                0.2      0            0.223607                 0.3
# 21                0.4      0            0.300000                 0.5
# 11                0.2      0            0.374166                 0.6
# 35                0.2      0            0.374166                 0.6
# 46                0.2      0            0.360555                 0.5
# 19                0.3      0            0.331662                 0.5
# 23                0.5      0            0.469042                 0.8
# 10                0.2      0            0.374166                 0.6
# 20                0.2      0            0.435890                 0.7
# 31                0.4      0            0.387298                 0.7
# 29                0.2      0            0.538516                 0.9
# 2                 0.2      0            0.509902                 0.8
# 34                0.1      0            0.469042                 0.8
# 30                0.2      0            0.538516                 0.9
# 37                0.1      0            0.469042                 0.8
#
#     chebyshev_distance
# 0                  0.0
# 17                 0.1
# 40                 0.1
# 39                 0.1
# 4                  0.1
# 7                  0.1
# 27                 0.1
# 28                 0.1
# 26                 0.2
# 48                 0.2
# 49                 0.2
# 21                 0.2
# 11                 0.3
# 35                 0.3
# 46                 0.3
# 19                 0.3
# 23                 0.3
# 10                 0.3
# 20                 0.3
# 31                 0.3
# 29                 0.4
# 2                  0.4
# 34                 0.4
# 30                 0.4
# 37                 0.4

# %% [markdown]
# # Minkowski Distance

# %%
def minkowski_distance(X, line, p):
    X_ = (abs((X - line)) ** p) ** (1 / p)
    return np.sum(X_, axis=1)

# %%
p = 3

# %%
df['minkowski_distance'] = minkowski_distance(X, X_line, p)

# %%
df.sort_values(by='minkowski_distance')[0:25]
# Out:
#     sepal length in cm  sepal width in cm  petal length in cm  \
# 0                  5.1                3.5                 1.4
# 17                 5.1                3.5                 1.4
# 4                  5.0                3.6                 1.4
# 39                 5.1                3.4                 1.5
# 28                 5.2                3.4                 1.4
# 27                 5.2                3.5                 1.5
# 40                 5.0                3.5                 1.3
# 7                  5.0                3.4                 1.5
# 49                 5.0                3.3                 1.4
# 19                 5.1                3.8                 1.5
# 46                 5.1                3.8                 1.6
# 36                 5.5                3.5                 1.3
# 21                 5.1                3.7                 1.5
# 48                 5.3                3.7                 1.5
# 35                 5.0                3.2                 1.2
# 26                 5.0                3.4                 1.6
# 11                 4.8                3.4                 1.6
# 10                 5.4                3.7                 1.5
# 1                  4.9                3.0                 1.4
# 43                 5.0                3.5                 1.6
# 6                  4.6                3.4                 1.4
# 20                 5.4                3.4                 1.7
# 31                 5.4                3.4                 1.5
# 2                  4.7                3.2                 1.3
# 9                  4.9                3.1                 1.5
#
#     petal width in cm  class  euclidean_distance  manhattan_distance  \
# 0                 0.2      0            0.000000                 0.0
# 17                0.3      0            0.100000                 0.1
# 4                 0.2      0            0.141421                 0.2
# 39                0.2      0            0.141421                 0.2
# 28                0.2      0            0.141421                 0.2
# 27                0.2      0            0.141421                 0.2
# 40                0.3      0            0.173205                 0.3
# 7                 0.2      0            0.173205                 0.3
# 49                0.2      0            0.223607                 0.3
# 19                0.3      0            0.331662                 0.5
# 46                0.2      0            0.360555                 0.5
# 36                0.2      0            0.412311                 0.5
# 21                0.4      0            0.300000                 0.5
# 48                0.2      0            0.300000                 0.5
# 35                0.2      0            0.374166                 0.6
# 26                0.4      0            0.316228                 0.6
# 11                0.2      0            0.374166                 0.6
# 10                0.2      0            0.374166                 0.6
# 1                 0.2      0            0.538516                 0.7
# 43                0.6      0            0.458258                 0.7
# 6                 0.3      0            0.519615                 0.7
# 20                0.2      0            0.435890                 0.7
# 31                0.4      0            0.387298                 0.7
# 2                 0.2      0            0.509902                 0.8
# 9                 0.1      0            0.469042                 0.8
#
#     chebyshev_distance  minkowski_distance
# 0                  0.0                 0.0
# 17                 0.1                 0.1
# 4                  0.1                 0.2
# 39                 0.1                 0.2
# 28                 0.1                 0.2
# 27                 0.1                 0.2
# 40                 0.1                 0.3
# 7                  0.1                 0.3
# 49                 0.2                 0.3
# 19                 0.3                 0.5
# 46                 0.3                 0.5
# 36                 0.4                 0.5
# 21                 0.2                 0.5
# 48                 0.2                 0.5
# 35                 0.3                 0.6
# 26                 0.2                 0.6
# 11                 0.3                 0.6
# 10                 0.3                 0.6
# 1                  0.5                 0.7
# 43                 0.4                 0.7
# 6                  0.5                 0.7
# 20                 0.3                 0.7
# 31                 0.3                 0.7
# 2                  0.4                 0.8
# 9                  0.4                 0.8

# %% [markdown]
# # KNN Brute Force

# %%
def idx_knn(X, line, k):
    ed = euclidean_distance(X, line)
    idx_sort = np.argsort(ed)
    return idx_sort[0:k]

# %% [markdown]
# # KNN Classifier

# %%
def knn_classifier(X, y, line, k):
    idx_knn_ = idx_knn(X, line, k=k)
    count = np.bincount(y[idx_knn_])
    return np.argmax(count)

# %%
X_train_std[0:1,]
# Out:
# array([[1.19452367, 0.30570892, 0.62281135, 0.49431153]])

# %%
y_train[:,]
# Out:
# array([1, 1, 0, 1, 0, 2, 0, 2, 1, 0, 1, 0, 2, 2, 2], dtype=int64)

# %%
line = X_train_std[0:1,]

# %%
k = 1
knn_classifier(X_train_std, y_train, line, k)
# Out:
# 1

# %%
k = 3
knn_classifier(X_train_std, y_train, line, k)
# Out:
# 2

# %%
k = 5
knn_classifier(X_train_std, y_train, line, k)
# Out:
# 2

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# k = 1
clf = KNeighborsClassifier(n_neighbors=1)
clf.fit(X_train_std, y_train)
clf.predict(line)
# Out:
# array([1], dtype=int64)

# %%
# k = 3
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train_std, y_train)
clf.predict(line)
# Out:
# array([2], dtype=int64)

# %%
# k = 5
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train_std, y_train)
clf.predict(line)
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # KNN Regressor

# %%
def knn_regressor(X, y, line, k):
    idx_knn_ = idx_knn(X, line, k=k)
    return np.mean(y[idx_knn_])

# %%
k = 1
knn_regressor(X_train_std, y_train, line, k)
# Out:
# 1.0

# %%
k = 3
knn_regressor(X_train_std, y_train, line, k)
# Out:
# 1.6666666666666667

# %%
k = 5
knn_regressor(X_train_std, y_train, line, k)
# Out:
# 1.6

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
# k = 1
knr = KNeighborsRegressor(n_neighbors=1)
knr.fit(X_train_std, y_train)
knr.predict(line)
# Out:
# array([1.])

# %%
# k = 3
knr = KNeighborsRegressor(n_neighbors=3)
knr.fit(X_train_std, y_train)
knr.predict(line)
# Out:
# array([1.66666667])

# %%
# k = 5
knr = KNeighborsRegressor(n_neighbors=5)
knr.fit(X_train_std, y_train)
knr.predict(line)
# Out:
# array([1.6])
